# %%
import pandas as pd
import plotly
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import numpy as np

# %% [markdown]
# ## Simple scatter plot

# %%
init_notebook_mode(connected=True)
# Read data
# Data Source: https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset
df = pd.read_csv('movie_metadata.csv')

# Define trace
# X-axis: Number of voted users.
# Y-axis: IMDB Score.
trace1 = Scatter(x= df['num_voted_users'], y=df['imdb_score'], mode = 'markers')

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format. 
iplot({
                         "data": [trace1], 
                         # <b> and </b>: Bold title 
                         # <br> use this for line break.
                        "layout": Layout(title="<b>Number of Voted Users Vs IMDB Score</b>", 
                                                   xaxis= dict(
                                                        title= '<b>Number of Voted Users</b>',
                                                        zeroline= False,
                                                        gridcolor='rgb(183,183,183)',
                                                        showline=True
                                                    ),
                                                    yaxis=dict(
                                                        title= '<b>IMDB_score</b>',
                                                        gridcolor='rgb(183,183,183)',
                                                        zeroline=False,
                                                        showline=True
                                                    ))
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="9b6c5a22-d7fc-479e-95d9-ff3e25e8a4bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9b6c5a22-d7fc-479e-95d9-ff3e25e8a4bd", [{"mode": "markers", "x": [886204.0, 471220.0, 275868.0, 1144337.0, 8.0, 212204.0, 383056.0, 294810.0, 462669.0, 321795.0, 371639.0, 240396.0, 330784.0, 522040.0, 181792.0, 548573.0, 149922.0, 995415.0, 370704.0, 268154.0, 354228.0, 451803.0, 211765.0, 483540.0, 149019.0, 316018.0, 793059.0, 272670.0, 202382.0, 418214.0, 522030.0, 411164.0, 557489.0, 306320.0, 383427.0, 235025.0, 323207.0, 242420.0, 175409.0, 321227.0, 264183.0, 101178.0, 223393.0, 544884.0, 286095.0, 278232.0, 465019.0, 514125.0, 395573.0, 106416.0, 362912.0, 222403.0, 381148.0, 326180.0, 333847.0, 62836.0, 273556.0, 53607.0, 718837.0, 121084.0, 283418.0, 72809.0, 139593.0, 42372.0, 286506.0, 148379.0, 1676169.0, 665575.0, 114553.0, 696338.0, 245333.0, 129601.0, 117927.0, 118992.0, 115099.0, 431620.0, 144337.0, 174578.0, 345198.0, 106072.0, 522371.0, 228554.0, 252257.0, 317542.0, 2138.0, 116994.0, 496749.0, 138661.0, 128306.0, 279093.0, 272534.0, 120798.0, 58137.0, 485430.0, 305340.0, 682155.0, 928227.0, 1468200.0, 374.0, 637246.0, 272223.0, 459346.0, 518537.0, 166137.0, 124185.0, 82380.0, 21352.0, 211971.0, 111609.0, 188457.0, 106446.0, 254111.0, 513158.0, 138863.0, 355137.0, 385670.0, 343648.0, 530870.0, 320284.0, 473887.0, 980946.0, 146019.0, 130272.0, 361924.0, 364948.0, 421658.0, 421818.0, 414070.0, 552503.0, 207839.0, 536314.0, 146766.0, 33042.0, 152826.0, 199039.0, 232187.0, 89442.0, 42372.0, 105902.0, 182718.0, 118951.0, 256695.0, 164238.0, 17590.0, 85086.0, 39956.0, 47900.0, 381672.0, 119213.0, 169914.0, 69757.0, 322395.0, 270207.0, 142440.0, 64322.0,
# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace
                                  ], 
                        "layout": Layout(title="Store Type Distribution",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='Store_Type.html',image='jpeg')
# Out:
# <div id="ec2c74ee-f766-45a6-b84f-16bff6bc7199" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ec2c74ee-f766-45a6-b84f-16bff6bc7199", [{"insidetextfont": {"color": "rgb(0,0,0)", "family": "Courier New, monospace", "size": 18}, "labels": ["A", "B", "C"], "marker": {"colors": ["rgb( 255, 182, 193)", "rgb(132,112,255)", "rgb(0,171,169)"]}, "values": [22.0, 17.0, 6.0], "type": "pie", "uid": "42c64fee-cade-11e8-85f4-dc85de6ac3aa"}], {"font": {"color": "rgb(0,0,0)", "family": "Courier New, monospace", "size": 18}, "title": "Store Type Distribution"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('ec2c74ee-f766-45a6-b84f-16bff6bc7199');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'Store_Type.html');}}</script>

# %% [markdown]
# ## Line Chart

# %%
init_notebook_mode(connected=True)

N = 500
random_x = np.linspace(0, 1, N)
random_y = np.random.randn(N)

# Define trace
trace =Scatter(x = random_x,y=random_y,marker = dict(color = 'rgb(128, 0, 0)',))

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace
                                  ], 
                        "layout": Layout(title="Line Chart",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='Line_chart.html',image='jpeg')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="c3a73921-3895-4f66-bbb8-3f6b30aa827a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3a73921-3895-4f66-bbb8-3f6b30aa827a", [{"marker": {"color": "rgb(128, 0, 0)"}, "x": [0.0, 0.002004008016032064, 0.004008016032064128, 0.0060120240480961915, 0.008016032064128256, 0.01002004008016032, 0.012024048096192383, 0.014028056112224447, 0.01603206412825651, 0.018036072144288574, 0.02004008016032064, 0.022044088176352703, 0.024048096192384766, 0.026052104208416832, 0.028056112224448895, 0.03006012024048096, 0.03206412825651302, 0.03406813627254509, 0.03607214428857715, 0.038076152304609215, 0.04008016032064128, 0.04208416833667334, 0.044088176352705406, 0.04609218436873747, 0.04809619238476953, 0.0501002004008016, 0.052104208416833664, 0.05410821643286573, 0.05611222444889779, 0.058116232464929855, 0.06012024048096192, 0.06212424849699398, 0.06412825651302605, 0.06613226452905811, 0.06813627254509018, 0.07014028056112225, 0.0721442885771543, 0.07414829659318636, 0.07615230460921843, 0.0781563126252505, 0.08016032064128256, 0.08216432865731463, 0.08416833667334668, 0.08617234468937875, 0.08817635270541081, 0.09018036072144288, 0.09218436873747494, 0.09418837675350701, 0.09619238476953906, 0.09819639278557113, 0.1002004008016032, 0.10220440881763526, 0.10420841683366733, 0.1062124248496994, 0.10821643286573146, 0.11022044088176351, 0.11222444889779558, 0.11422845691382764, 0.11623246492985971, 0.11823647294589178, 0.12024048096192384, 0.1222444889779559, 0.12424849699398796, 0.12625250501002003, 0.1282565130260521, 0.13026052104208416, 0.13226452905811623, 0.1342685370741483, 0.13627254509018036, 0.13827655310621242, 0.1402805611222445, 0.14228456913827653, 0.1442885771543086, 0.14629258517034066, 0.14829659318637273, 0.1503006012024048, 0.15230460921843686, 0.15430861723446893, 0.156312625250501, 0.15831663326653306, 0.16032064128256512, 0.1623246492985972, 0.16432865731462926, 0.16633266533066132, 0.16833667334669336, 0.17034068136272543, 0.1723446893787575, 0.17434869739478956, 0.17635270541082163, 0.1783567134268537, 0.18036072144288576, 0.18236472945891782, 0.1843687374749499, 0.18637274549098196, 0.18837675350701402, 0.1903807615230461, 0.19238476953907813, 0.1943887775551102, 0.19639278557114226, 0.19839679358717432, 0.2004008016032064, 0.20240480961923846, 0.20440881763527052, 0.2064128256513026, 0.20841683366733466, 0.21042084168336672, 0.2124248496993988, 0.21442885771543085, 0.21643286573146292, 0.21843687374749496, 0.22044088176352702, 0.2224448897795591, 0.22444889779559116, 0.22645290581162322, 0.2284569138276553, 0.23046092184368736, 0.23246492985971942, 0.2344689378757515, 0.23647294589178355, 0.23847695390781562, 0.24048096192384769, 0.24248496993987975, 0.2444889779559118, 0.24649298597194386, 0.24849699398797592, 0.250501002004008, 0.25250501002004005, 0.2545090180360721, 0.2565130260521042, 0.25851703406813625, 0.2605210420841683, 0.2625250501002004, 0.26452905811623245, 0.2665330661322645, 0.2685370741482966, 0.27054108216432865, 0.2725450901803607, 0.2745490981963928, 0.27655310621242485, 0.2785571142284569, 0.280561122244489, 0.282565130260521, 0.28456913827655306, 0.2865731462925851, 0.2885771543086172, 0.29058116232464926, 0.2925851703406813, 0.2945891783567134, 0.29659318637274545, 0.2985971943887775, 0.3006012024048096, 0.30260521042084165, 0.3046092184368737, 0.3066132264529058, 0.30861723446893785, 0.3106212424849699, 0.312625250501002, 0.31462925851703405, 0.3166332665330661, 0.3186372745490982, 0.32064128256513025, 0.3226452905811623, 0.3246492985971944, 0.32665330661322645, 0.3286573146292585, 0.3306613226452906, 0.33266533066132264, 0.33466933867735466, 0.3366733466933867, 0.3386773547094188, 0.34068136272545085, 0.3426853707414829, 0.344689378757515, 0.34669338677354705, 0.3486973947895791, 0.3507014028056112, ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('c3a73921-3895-4f66-bbb8-3f6b30aa827a');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'Line_chart.html');}}</script>

# %% [markdown]
# ## Horizontal histogram

# %%
# Generate data randomly
x = np.random.randn(500)

# Define trace
# Horizontal chart: set value for y-axis
trace =Histogram(y=x,showlegend=True,marker = dict(color = 'rgb(100, 50, 150)',))

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace
                                  ], 
                        "layout": Layout(title="Horizontal Histogram",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='Horizontal_Histogram.html',image='jpeg')
# Out:
# <div id="5ee1e436-6474-48bb-9758-bd57f265e20b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
961766275, 1.0927722804532813, 1.12865448667587, 0.6339334398625158, -1.1175567382466924, 0.8260307684348609, -0.9312203580350221, 0.890848184536763, -0.9877850661339584, 0.24955535227122597, -2.1528010527736114, 0.20458900044173645, -0.8347172361440297, -0.3363087544163322, -0.3666471594315339, -0.24835503236985437, -0.42197288715457415, -0.07647134052196397, 0.7676793761959354, 0.3513843997829668, 1.2593792511999484, -0.9507321187637072, 2.039154147950443, 1.3042240441197033, -0.324305109664172, 0.6217808075324431, 0.10669275593920101, 0.7812659157830084, 0.51553201105145, -0.0534154 ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('5ee1e436-6474-48bb-9758-bd57f265e20b');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'Horizontal_Histogram.html');}}</script>

# %% [markdown]
# ## Normalized Histogram

# %%
# Generate data randomly
x = np.random.randn(500)

# Define trace
# Normalized parameter: histnorm='probability'
trace =Histogram(x=x,showlegend=True,marker = dict(color = 'rgb(0, 0, 128)',),histnorm='probability')

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace
                                  ], 
                        "layout": Layout(title="Normalized Histogram",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='Normalized_Histogram.html',image='jpeg')
# Out:
# <div id="be9d1f97-6b2b-49d4-85bc-deb4e5799daa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be9d1f97-6b2b-49d4-85bc-deb4e5799daa", [{"histnorm": "probability", "marker": {"color": "rgb(0, 0, 128)"}, "showlegend": true, "x": [0.5640581918392957, -0.06516505492667295, 1.1286427421246998, -0.18514671599093385, 0.6172788664181573, -1.8902507804652902, -1.264165315492537, 1.189372045077737, 1.2220967420811633, 0.6233288443290186, 1.909984725130272, -1.6939254026334563, -0.38017830070426273, 0.6075929204458296, 0.8505683115106589, -0.5063654605371161, 0.8290017563523258, -0.13518490551506884, -1.1678759755162276, -0.5630695624464793, 0.7016447312378482, -1.1052438852557747, 0.27586838284025544, -0.057432835054177206, -1.3515419715179104, -0.9208284895478184, -0.13165379416331846, -1.9126382415600276, -0.21405696256630985, 0.3052204135363239, -0.20437112558621065, 0.6239276672187958, -0.09146394776392276, -0.3912245712992663, 0.3655501417052965, -0.6923956550482524, -0.0091284353041457, -0.8132223709017762, 1.448442388254536, -1.1232037638675336, -0.3271449102618191, -0.5051038071375545, -0.0628507583878859, -0.4424890283133605, 0.3914288462145013, -0.5279167424467487, 0.5599671902939577, -1.3963725749166684, 0.7708444091849037, 0.026670287742229352, -0.1543334680318606, -0.8526346388779595, 0.8133364773296029, -1.321172032614659, 1.0997807524360357, -1.800111233892186, 0.31214431949414345, -0.49946381197812517, 0.8981660193977805, -0.46106205019588203, -0.6182080594261113, 1.0912187041031325, -0.15418870263253734, -0.0319967239788688, 0.5385793540196742, -0.6287550657631636, -1.2459709924699678, -1.0430361270253512, 2.0366688311242673, -0.12418101433495846, 0.6578279706305978, 1.5922540027480676, 0.4991477063167113, -0.08688058895476859, 0.603764570997869, 0.9245170144627872, -0.3248801812022953, -0.08292250116161093, 0.7811874285427565, -0.16039036456311154, -0.6960295254434676, -0.8279966265188096, 0.12243423841740982, 1.129265047215935, 0.4400295627945688, -0.7145845590580696, 0.9619776316451246, 0.3771031012784135, -0.007058069790795817, -1.1040190320790042, 0.376346744216382, -0.6008909199036908, 0.6649957745632549, 0.5047519313784457, -1.0481922977601685, 0.23795969065672282, -0.06834566937483055, -0.7723132368079709, 0.5214619520207079, -2.6129278487838956, -0.15066455685888036, 1.1234545782120904, 0.9344442842785557, -1.0497667564935682, -0.7190574318989233, -0.9966680996026355, 0.4011338117789067, -1.640626782172836, -0.723846125451478, -0.5870683165562383, 0.42840478630314566, 0.8463257379938968, 0.8055860308229281, -0.9534829394319082, 1.8719795465465978, 0.024342780731864522, 0.7315744894653411, 1.5324781385602673, 2.2674421939730496, -0.21210754342145455, 0.64962182712628, -0.2711095343978908, -0.9486333214365549, 1.2432626112728364, -0.5593083613661785, 0.9304841102793823, 1.6955487323717353, -0.9779503179376758, 0.9522020529350472, -2.652555422772599, -1.0423625655365163, 0.47960059107115466, -0.10788521917864169, -0.9030755958705472, -0.9681169057499598, -0.435946837669689, -1.2175318691781123, -2.2451532924054614, 0.21085721190477386, -1.0258634638451254, -0.33530156889131446, -0.6762217325746408, -0.8567752611399773, -0.2563923658687158, 0.8440272281450784, -1.8621989030371353, -0.6316976845979995, -1.2875086036393135, 1.4525400856260273, 0.17123935390822226, 0.3777782792608651, 0.02326816676789577, -0.6245759634952818, 1.3206161897608601, -0.1751229561917909, -0.2301998208670251, 0.4703338872031082, 0.38148175209033425, -0.6255540346411151, -0.7243013924838189, 0.2921860154121974, 0.4948311643755698, -0.3521640584520308, -0.2532580175272541, -1.6065950485767972, 0.1503236609119392, 0.24498387279802614, -0.6664767759651524, 0.16061902662403, -0.4862449453593599, -0.08340408769986575, 0.5133940339864802, 0.63113029056434, 0.607 ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('be9d1f97-6b2b-49d4-85bc-deb4e5799daa');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'Normalized_Histogram.html');}}</script>

# %% [markdown]
# ### Box plot

# %%
# Create data 
y0 = np.random.randn(50)-1
y1 = np.random.randn(50)+1

# Define trace
trace1 =Box(x=y0,showlegend=True,name='Trace_y0')
trace2 =Box(x=y1,showlegend=True,name='Trace_y1')

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace1,trace2
                                  ], 
                        "layout": Layout(title="Basic Horizontal Box Chart",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='basic_horizontal_box_chart.html',image='jpeg')
# Out:
# <div id="e171f8b1-0547-4a3e-85cd-f2abdd0174e0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e171f8b1-0547-4a3e-85cd-f2abdd0174e0", [{"name": "Trace_y0", "showlegend": true, "x": [-0.13083996823214883, -0.3763129628436521, 0.40937912398475595, -1.4129727115471284, -2.460243168231255, -0.1809415100470544, -1.9306516737226156, -1.6049158322704777, -0.30193002493899346, -1.0695826681154477, -3.637365244909374, -1.3935501212591912, -0.7934481336459673, -0.5622424627310476, -1.2786864343177915, -1.0418663702694444, 0.6055004853738024, 0.9603307813301498, -0.4750734419914895, 0.06562206480635258, -0.7569062364359143, -2.074279275723292, 0.3549882390402608, -1.4483924114968236, -1.8527375256285163, -1.880395386607317, -1.8117953356193863, -1.9304436918994958, -0.851530570876249, -2.060749966203953, -1.3838665227081046, -1.9089729471934265, -1.526179917999701, 0.15219131905110017, 0.6888672700612377, -0.25035817816487094, -0.7593551448559643, -0.7877661391127692, -0.8743972982707362, -0.5740305498869729, -1.4661413060141861, -1.6035825660200103, -1.3941791393631227, 0.03638746664285519, 1.0186377026351257, -1.0160762687472091, -1.4801843634766987, -2.4356721002223782, -2.293023191518512, -1.9181761184295891], "type": "box", "uid": "1893c6ae-cadf-11e8-b08f-dc85de6ac3aa"}, {"name": "Trace_y1", "showlegend": true, "x": [1.7475060198580783, 0.758158475415666, 0.6021276235846181, 1.1802076215408117, 1.3590194580365242, 1.5072135500822852, 0.20903289176460849, 1.2297235154298851, 0.5771910855935574, 0.35510903677568817, 0.3774558842502582, 2.170592076420095, 0.5921633400457724, 0.1794931718505658, 2.244692362481395, -0.13500277124055238, 2.2897572244685476, 1.77465868607855, 0.34840923531682433, -0.403313318914976, 1.5366693912995983, 2.5562631579341195, 1.43919543760664, 2.329393104663538, 0.7223035941790059, 1.915959576739926, 1.4526699974786854, 0.17826428809908978, 1.6950688135416359, 2.2768253178164355, 0.616846801235919, 1.6661805945522543, 0.8730672395818975, -0.5845108338986977, 0.24055740114113788, 1.4386934952567259, 1.4645251721707448, 2.715338775608143, 1.752472918149809, 1.5055226571327, 0.49721892144711477, -0.22875507126696926, 0.9686870972725513, 0.8506993866377792, 1.7535766030526925, 2.31625332596099, 2.0612306271169465, 2.0802876093662768, 2.244576304061354, 1.3510759219524493], "type": "box", "uid": "1893c6af-cadf-11e8-b90d-dc85de6ac3aa"}], {"font": {"color": "rgb(0,0,0)", "family": "Courier New, monospace", "size": 18}, "title": "Basic Horizontal Box Chart"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('e171f8b1-0547-4a3e-85cd-f2abdd0174e0');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'basic_horizontal_box_chart.html');}}</script>

# %% [markdown]
# ## Atlas map

# %%
df = pd.read_csv('starbucks_us_locations.csv')
df.columns = ['Longitude','Latitude','ADR_Line_1','ADR_Line_2']
 
# Atlas Map: Scattergeo type 
data = [ dict(
    type = 'scattergeo',
    lat = df['Latitude'],
    lon = df['Longitude'],
    text = df['ADR_Line_2'],
    mode = 'markers',
    marker = dict(color = 'rgb(128, 112, 0)'),
    )]

# In layout you can set scope to USA and projetions to 'albers usa', this will only display USA map.               
layout = dict(
    title = "STARBUCKS LOCATIONS IN USA",
    # Font type,size and color for title
    font=dict(family='Courier New, monospace', size=18, color='rgb(110,0,0)'),
    geo = dict(
        scope = 'usa',
        projection=dict(type='albers usa'),
        showframe = False,
        showland = True,
        showcountries = True,
        landcolor = 'rgb(0,1,12)',
        subunitcolor = 'rgb(0,150,0)',
        countrycolor = 'rgb(22,100,0)',
        coastlinecolor = "rgb(0, 0, 0)",
        countrywidth = 2,
        oceancolor = 'rgb(0, 0, 190)',
        coastlinewidth=4,
        subunitwidth = 0.5
        )
    )

iplot({"data":data, "layout":layout},filename = 'starbucks_stores_usa_atlas_map.html')
# Out:
# <div id="175e3ecd-841b-4416-87eb-9fc99899e143" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
33.56562937, 33.68161278, 33.59583208, 33.67387, 33.63803903, 33.61039102, 33.67893289, 33.654005299999994, 33.4468558, 33.79837379999999, 33.6852244, 33.4624, 33.44834, 33.3061, 33.4658, 33.6114, 33.50986629, 33.30504059, 33.75632629, 33.49451344, 33.48751933, 33.53819933, 33.34882, 33.3904, 33.48043, 33.64060689, 33.4522, 33.599728000000006, 33.47661835, 33.3777377, 33.4800915, 33.43494437, 33.515962, 33.52370909, 33.64059753, 33.3777377, 33.6402, 33.61082474, 33.52396181, 33.62643855, 33.30520451, 33.517703999999995, 33.465897, 33.478552, 33.50830018, 33.67922567, 33.50921915, 33.55299694, 33.50927007, 33.45233361, 33.58185449, 33.49473543, 33.79912281, 33.466037, 33.67081429, 33.60684615, 33.50935886, 33.52661192, 33.44932599, 33.71280288, 33.48396422, 33.677, 33.59980423, 33.62230287, 33.65523804, 33.67736785, 33.64061119, 33.58299855, 33.61096475, 34.55943317, 34.58534588, 34.56263, 34.546028, 33.232929999999996, 33.2631914, 31.9555, 33.62960993, 33.5095706, 33.589592200000006, 33.625859999999996, 33.58770455, 33.62030812, 33.62532392, 33.4949, 33.50925641, 33.67550663, 33.584590000000006, 33.62535938, 33.638613299999996, 33.58247141, 33.623804, 33.48593131, 33.62252143 ...

# %% [markdown]
# ## Area chart

# %%
trace1 =Scatter(x=[1, 2, 3, 4],y=[0, 2, 3, 5],showlegend=True,marker = dict(color = 'rgb(128, 0, 0)',),name='Trace_1',fill='tozeroy')
trace2 =Scatter(x=[1, 2, 3, 4],y=[3, 5, 1, 7],showlegend=True,marker = dict(color = 'rgb(0, 128, 0)',),name='Trace_2',fill='tonexty')

# Create chart 
# Output will be stored as a html file. 
# Whenever we will open output html file, one popup option will ask us about if want to save it in jpeg format.
# Font family can be used in a layout to define font type, font size and font color for title           
iplot({
                         "data": [
                                  trace1,trace2
                                  ], 
                        "layout": Layout(title="Area Chart",font=dict(family='Courier New, monospace', size=18, color='rgb(0,0,0)'))
                                  },filename='Area_chart.html',image='jpeg')
# Out:
# <div id="8580a0f5-b9b3-485c-8b65-3f4b57cd08f2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8580a0f5-b9b3-485c-8b65-3f4b57cd08f2", [{"fill": "tozeroy", "marker": {"color": "rgb(128, 0, 0)"}, "name": "Trace_1", "showlegend": true, "x": [1, 2, 3, 4], "y": [0, 2, 3, 5], "type": "scatter", "uid": "d776d106-cadf-11e8-94a6-dc85de6ac3aa"}, {"fill": "tonexty", "marker": {"color": "rgb(0, 128, 0)"}, "name": "Trace_2", "showlegend": true, "x": [1, 2, 3, 4], "y": [3, 5, 1, 7], "type": "scatter", "uid": "d776d107-cadf-11e8-a310-dc85de6ac3aa"}], {"font": {"color": "rgb(0,0,0)", "family": "Courier New, monospace", "size": 18}, "title": "Area Chart"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('8580a0f5-b9b3-485c-8b65-3f4b57cd08f2');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('jpeg', 600, 800, 'Area_chart.html');}}</script>
