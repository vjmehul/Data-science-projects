# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import math
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression, SelectKBest

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Rebuiding variables into categorical

# %%
refactor_vars = ['PoolQC', 'Alley', 'Fence', 'MiscFeature', 'GarageCond', 'GarageQual', 'GarageFinish', 'GarageType', 'FireplaceQu', 'BsmtFinType2', 'BsmtFinType1', 'BsmtExposure', 'BsmtCond', 'BsmtQual']

for var in refactor_vars:
    df_train[var].fillna(value='N', inplace=True)
    
for var in ['YearBuilt', 'YearRemodAdd']:
    df_train.loc[df_train[var] <= 1889, var] = 0
    df_train.loc[(df_train[var] >= 1890) & (df_train[var] < 1900), var] = 1
    df_train.loc[(df_train[var] >= 1900) & (df_train[var] < 1910), var] = 2
    df_train.loc[(df_train[var] >= 1910) & (df_train[var] < 1920), var] = 3
    df_train.loc[(df_train[var] >= 1920) & (df_train[var] < 1930), var] = 4
    df_train.loc[(df_train[var] >= 1930) & (df_train[var] < 1940), var] = 5
    df_train.loc[(df_train[var] >= 1940) & (df_train[var] < 1950), var] = 6
    df_train.loc[(df_train[var] >= 1950) & (df_train[var] < 1960), var] = 7
    df_train.loc[(df_train[var] >= 1960) & (df_train[var] < 1970), var] = 8
    df_train.loc[(df_train[var] >= 1970) & (df_train[var] < 1980), var] = 9
    df_train.loc[(df_train[var] >= 1980) & (df_train[var] < 1990), var] = 10
    df_train.loc[(df_train[var] >= 1990) & (df_train[var] < 2000), var] = 11
    df_train.loc[(df_train[var] >= 2000) & (df_train[var] < 2010), var] = 12
    df_train.loc[(df_train[var] >= 2010), var] = 13
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave     N      Reg
# 1   2          20       RL         80.0     9600   Pave     N      Reg
# 2   3          60       RL         68.0    11250   Pave     N      IR1
# 3   4          70       RL         60.0     9550   Pave     N      IR1
# 4   5          60       RL         84.0    14260   Pave     N      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0      N     N           N       0
# 1         Lvl    AllPub    ...            0      N     N           N       0
# 2         Lvl    AllPub    ...            0      N     N           N       0
# 3         Lvl    AllPub    ...            0      N     N           N       0
# 4         Lvl    AllPub    ...            0      N     N           N       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Missing value treatement

# %%
# finding columns with missing values

missing_value=df_train.isnull().sum() /len(df_train)
missing_value=pd.DataFrame({'column_name':missing_value.index,'missing_per':missing_value.values})
missing_value[missing_value['missing_per']>0]
# Out:
#     column_name  missing_per
# 3   LotFrontage     0.177397
# 25   MasVnrType     0.005479
# 26   MasVnrArea     0.005479
# 42   Electrical     0.000685
# 59  GarageYrBlt     0.055479

# %%
df_train=df_train.dropna(subset=['LotFrontage','MasVnrType','MasVnrArea','Electrical','GarageYrBlt'])

# %%
missing_value=df_train.isnull().sum() /len(df_train)
missing_value=pd.DataFrame({'column_name':missing_value.index,'missing_per':missing_value.values})
missing_value[missing_value['missing_per']>0]
# Out:
# Empty DataFrame
# Columns: [column_name, missing_per]
# Index: []

# %% [markdown]
# ### Collinearity check
# * we want to find variables which are specifically correlated with selling price

# %%
df_train_corr=df_train.corr()
stack_cor = df_train_corr.stack()
stack_cor['SalePrice'].abs().sort_values(axis=0, ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.798002
# GrLivArea        0.705139
# GarageCars       0.647093
# GarageArea       0.619318
# TotalBsmtSF      0.615990
# 1stFlrSF         0.608092
# FullBath         0.566934
# TotRmsAbvGrd     0.547148
# YearBuilt        0.519705
# YearRemodAdd     0.505862
# GarageYrBlt      0.505255
# MasVnrArea       0.488629
# Fireplaces       0.461885
# BsmtFinSF1       0.390280
# LotFrontage      0.344297
# OpenPorchSF      0.343301
# WoodDeckSF       0.336875
# 2ndFlrSF         0.307071
# LotArea          0.299960
# HalfBath         0.268991
# BsmtFullBath     0.236655
# BsmtUnfSF        0.213063
# BedroomAbvGr     0.166854
# EnclosedPorch    0.154924
# KitchenAbvGr     0.140543
# OverallCond      0.124511
# ScreenPorch      0.110379
# PoolArea         0.092476
# MSSubClass       0.087936
# MoSold           0.051478
# Id               0.046872
# BsmtHalfBath     0.036560
# MiscVal          0.036070
# 3SsnPorch        0.030756
# BsmtFinSF2       0.028078
# YrSold           0.011840
# LowQualFinSF     0.001503
# dtype: float64

# %% [markdown]
# ### Select top correlated variables and plotting them

# %%
interest_vars = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 
        'YearBuilt', 'YearRemodAdd']
predictors = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 
        'YearBuilt', 'YearRemodAdd']
sns.pairplot(df_train[predictors])

# %%
selector = SelectKBest(f_regression, k='all')
selector.fit(df_train[predictors], df_train['SalePrice'])
selector_scores = pd.DataFrame(data={'F-Score': selector.scores_, 'P-Value': selector.pvalues_}, index=predictors)
selector_scores
# Out:
#                   F-Score        P-Value
# OverallQual   1960.256689  3.908088e-248
# GrLivArea     1105.642408  3.968425e-169
# GarageCars     805.372988  7.138113e-134
# TotalBsmtSF    683.608460  5.652158e-118
# 1stFlrSF       655.972390  3.240932e-114
# FullBath       529.544742   3.091990e-96
# TotRmsAbvGrd   477.708426   1.847374e-88
# YearBuilt      413.701836   1.688090e-78
# YearRemodAdd   384.478692   8.233530e-74

# %% [markdown]
# ## Checking linear regression assuptions
# ### MULTICOLLINEARITY

# %%
fig, ax = plt.subplots(figsize=(10,10))
corr_sub_matrix = df_train[interest_vars].corr()
sns.heatmap(corr_sub_matrix, annot=True, vmax=0.8)

# %% [markdown]
# * We can see that 1stFlrSF and TotalBsmtSF are very highly correlated, as are TotRmsAbvGrd and GrLivArea. TotalBsmtSF and GrLivArea have the stronger correlations with selling price, so we'll eliminate the other variables.

# %%
predictors.remove('1stFlrSF')
interest_vars.remove('1stFlrSF')
predictors.remove('TotRmsAbvGrd')
interest_vars.remove('TotRmsAbvGrd')


qual_predictors = ['OverallQual', 'GarageCars', 'FullBath', 'YearBuilt', 'YearRemodAdd']

# %% [markdown]
# ## Normality
# ### We'll examine our continuous variables' distributions for normality, starting with our dependent variable.

# %%
sp.stats.probplot(df_train['SalePrice'], plot=plt)
df_train['SalePrice'].skew()
# Out:
# 1.9323038633229828

# %%
sns.distplot(df_train['SalePrice'], fit=sp.stats.norm)
# Out:
# C:\Users\MVJ\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_train['SalePrice'] = np.log(df_train['SalePrice'])
sp.stats.probplot(df_train['SalePrice'], plot=plt)
df_train['SalePrice'].skew()
# Out:
# 0.3172047296130167

# %%
sns.distplot(df_train['SalePrice'], fit=sp.stats.norm)
# Out:
# C:\Users\MVJ\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# * Another log transformation should remedy this curve, but there's a hang-up that shows up in the plot below. We won't be able to perform a log transformation if there are zero values in the basement square footage data. We'll have to set the existence of a basement as a condition, and perform a log transformation on the observations with a basement.

# %%
# Create a binary variable for having or not having a basement

df_train['HasBsmt'] = pd.Series(len(df_train['TotalBsmtSF']), index=df_train.index)
df_train['HasBsmt'] = 0

# Where TotalBsmtSF is not 0, HasBsmt is 1

df_train.loc[df_train['TotalBsmtSF'] > 0, 'HasBsmt'] = 1

# And our log transformation

df_train.loc[df_train['HasBsmt'] == 1,'TotalBsmtSF'] = np.log(df_train['TotalBsmtSF'])
# Out:
# C:\Users\MVJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':

# %%
df_train.drop('HasBsmt', axis=1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave     N      Reg
# 1        2          20       RL         80.0     9600   Pave     N      Reg
# 2        3          60       RL         68.0    11250   Pave     N      IR1
# 3        4          70       RL         60.0     9550   Pave     N      IR1
# 4        5          60       RL         84.0    14260   Pave     N      IR1
# 5        6          50       RL         85.0    14115   Pave     N      IR1
# 6        7          20       RL         75.0    10084   Pave     N      Reg
# 8        9          50       RM         51.0     6120   Pave     N      Reg
# 9       10         190       RL         50.0     7420   Pave     N      Reg
# 10      11          20       RL         70.0    11200   Pave     N      Reg
# 11      12          60       RL         85.0    11924   Pave     N      IR1
# 13      14          20       RL         91.0    10652   Pave     N      IR1
# 15      16          45       RM         51.0     6120   Pave     N      Reg
# 17      18          90       RL         72.0    10791   Pave     N      Reg
# 18      19          20       RL         66.0    13695   Pave     N      Reg
# 19      20          20       RL         70.0     7560   Pave     N      Reg
# 20      21          60       RL        101.0    14215   Pave     N      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave     N      Reg
# 23      24         120       RM         44.0     4224   Pave     N      Reg
# 25      26          20       RL        110.0    14230   Pave     N      Reg
# 26      27          20       RL         60.0     7200   Pave     N      Reg
# 27      28          20       RL         98.0    11478   Pave     N      Reg
# 28      29          20       RL         47.0    16321   Pave     N      IR1
# 29      30          30       RM         60.0     6324   Pave     N      IR1
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 32      33          20       RL         85.0    11049   Pave     N      Reg
# 33      34          20       RL         70.0    10552   Pave     N      IR1
# 34      35         120       RL         60.0     7313   Pave     N      Reg
# 35      36          60       RL        108.0    13418   Pave     N      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1420  1421          60       RL         90.0    11700   Pave     N      Reg
# 1421  1422         120       RL         53.0     4043   Pave     N      Reg
# 1422  1423         120       RM         37.0     4435   Pave     N      Reg
# 1425  1426          20       RL         80.0    10721   Pave     N      IR1
# 1426  1427          60       RL         81.0    10944   Pave     N      IR1
# 1427  1428          50       RL         60.0    10930   Pave  Grvl      Reg
# 1428  1429          30       RM         60.0     7200   Pave     N      Reg
# 1430  1431          60       RL         60.0    21930   Pave     N      IR3
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave     N      IR1
# 1434  1435          20       RL         80.0    17400   Pave     N      Reg
# 1435  1436          20       RL         80.0     8400   Pave     N      Reg
# 1436  1437          20       RL         60.0     9000   Pave     N      Reg
# 1437  1438          20       RL         96.0    12444   Pave     N      Reg
# 1438  1439          20       RM         90.0     7407   Pave     N      Reg
# 1439  1440          60       RL         80.0    11584   Pave     N      Reg
# 1440  1441          70       RL         79.0    11526   Pave     N      IR1
# 1442  1443          60       FV         85.0    11003   Pave     N      Reg
# 1444  1445          20       RL         63.0     8500   Pave     N      Reg
# 1445  1446          85       RL         70.0     8400   Pave     N      Reg
# 1447  1448          60       RL         80.0    10000   Pave     N      Reg
# 1448  1449          50       RL         70.0    11767   Pave     N      Reg
# 1451  1452          20       RL         78.0     9262   Pave     N      Reg
# 1452  1453         180       RM         35.0     3675   Pave     N      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave     N      Reg
# 1456  1457          20       RL         85.0    13175   Pave     N      Reg
# 1457  1458          70       RL         66.0     9042   Pave     N      Reg
# 1458  1459          20       RL         68.0     9717   Pave     N      Reg
# 1459  1460          20       RL         75.0     9937   Pave     N      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    ...            0      N      N           N
# 1            Lvl    AllPub    ...            0      N      N           N
# 2            Lvl    AllPub    ...            0      N      N           N
# 3            Lvl    AllPub    ...            0      N      N           N
# 4            Lvl    AllPub    ...            0      N      N           N
# 5            Lvl    AllPub    ...            0      N  MnPrv        Shed
# 6            Lvl    AllPub    ...            0      N      N           N
# 8            Lvl    AllPub    ...            0      N      N           N
# 9            Lvl    AllPub    ...            0      N      N           N
# 10           Lvl    AllPub    ...            0      N      N           N
# 11           Lvl    AllPub    ...            0      N      N           N
# 13           Lvl    AllPub    ...            0      N      N           N
# 15           Lvl    AllPub    ...            0      N  GdPrv           N
# 17           Lvl    AllPub    ...            0      N      N        Shed
# 18           Lvl    AllPub    ...            0      N      N           N
# 19           Lvl    AllPub    ...            0      N  MnPrv           N
# 20           Lvl    AllPub    ...            0      N      N           N
# 21           Bnk    AllPub    ...            0      N  GdPrv           N
# 22           Lvl    AllPub    ...            0      N      N           N
# 23           Lvl    AllPub    ...            0      N      N           N
# 25           Lvl    AllPub    ...            0      N      N           N
# 26           Lvl    AllPub    ...            0      N      N           N
# 27           Lvl    AllPub    ...            0      N      N           N
# 28           Lvl    AllPub    ...            0      N      N           N
# 29           Lvl    AllPub    ...            0      N      N           N
# 30           Lvl    AllPub    ...            0      N  MnPrv           N
# 32           Lvl    AllPub    ...            0      N      N           N
# 33           Lvl    AllPub    ...            0      N      N           N
# 34           Lvl    AllPub    ...            0      N      N           N
# 35           Lvl    AllPub    ...            0      N      N           N
# ...          ...       ...    ...          ...    ...    ...         ...
# 1420         Lvl    AllPub    ...            0      N      N           N
# 1421         Lvl    AllPub    ...            0      N      N           N
# 1422         Lvl    AllPub    ...            0      N      N           N
# 1425         Lvl    AllPub    ...            0      N      N           N
# 1426         Lvl    AllPub    ...            0      N      N           N
# 1427         Bnk    AllPub    ...            0      N      N           N
# 1428         Lvl    AllPub    ...            0      N  MnPrv           N
# 1430         Lvl    AllPub    ...            0      N      N           N
# 1432         Lvl    AllPub    ...            0      N      N           N
# 1433         Lvl    AllPub    ...            0      N      N           N
# 1434         Low    AllPub    ...            0      N      N           N
# 1435         Lvl    AllPub    ...            0      N  GdPrv           N
# 1436         Lvl    AllPub    ...            0      N   GdWo           N
# 1437         Lvl    AllPub    ...            0      N      N           N
# 1438         Lvl    AllPub    ...            0      N  MnPrv           N
# 1439         Lvl    AllPub    ...            0      N      N           N
# 1440         Bnk    AllPub    ...            0      N      N           N
# 1442         Lvl    AllPub    ...            0      N      N           N
# 1444         Lvl    AllPub    ...            0      N      N           N
# 1445         Lvl    AllPub    ...            0      N      N           N
# 1447         Lvl    AllPub    ...            0      N      N           N
# 1448         Lvl    AllPub    ...            0      N   GdWo           N
# 1451         Lvl    AllPub    ...            0      N      N           N
# 1452         Lvl    AllPub    ...            0      N      N           N
# 1454         Lvl    AllPub    ...            0      N      N           N
# 1455         Lvl    AllPub    ...            0      N      N           N
# 1456         Lvl    AllPub    ...            0      N  MnPrv           N
# 1457         Lvl    AllPub    ...            0      N  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0      N      N           N
# 1459         Lvl    AllPub    ...            0      N      N           N
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2   2008        WD         Normal  12.247694
# 1          0      5   2007        WD         Normal  12.109011
# 2          0      9   2008        WD         Normal  12.317167
# 3          0      2   2006        WD        Abnorml  11.849398
# 4          0     12   2008        WD         Normal  12.429216
# 5        700     10   2009        WD         Normal  11.870600
# 6          0      8   2007        WD         Normal  12.634603
# 8          0      4   2008        WD        Abnorml  11.774520
# 9          0      1   2008        WD         Normal  11.678440
# 10         0      2   2008        WD         Normal  11.771436
# 11         0      7   2006       New        Partial  12.751300
# 13         0      8   2007       New        Partial  12.540758
# 15         0      7   2007        WD         Normal  11.790557
# 17       500     10   2006        WD         Normal  11.407565
# 18         0      6   2008        WD         Normal  11.976659
# 19         0      5   2009       COD        Abnorml  11.842229
# 20         0     11   2006       New        Partial  12.692503
# 21         0      6   2007        WD         Normal  11.845103
# 22         0      9   2008        WD         Normal  12.345835
# 23         0      6   2007        WD         Normal  11.774520
# 25         0      7   2009        WD         Normal  12.454104
# 26         0      5   2010        WD         Normal  11.811547
# 27         0      5   2010        WD         Normal  12.631340
# 28         0     12   2006        WD         Normal  12.242887
# 29         0      5   2008        WD         Normal  11.134589
# 30         0      7   2008        WD         Normal  10.596635
# 32         0      1   2008        WD         Normal  12.100156
# 33         0      4   2010        WD         Normal  12.016726
# 34         0      8   2007        WD         Normal  12.533576
# 35         0      9   2006        WD         Normal  12.641097
# ...      ...    ...    ...       ...            ...        ...
# 1420       0      5   2006        WD         Normal  12.100156
# 1421       0      7   2010        WD         Normal  11.755872
# 1422       0      3   2008        WD         Normal  11.824080
# 1425       0     10   2008        WD         Normal  11.863582
# 1426       0      8   2008        WD         Normal  12.509874
# 1427       0      4   2008        WD         Normal  11.849398
# 1428       0      2   2010        WD        Abnorml  11.686879
# 1430       0      7   2006        WD         Normal  12.165980
# 1432       0      8   2007        WD         Normal  11.074421
# 1433       0      5   2008        WD         Normal  12.136187
# 1434       0      5   2006        WD         Normal  11.982929
# 1435       0      7   2008       COD        Abnorml  12.066811
# 1436       0      5   2007        WD         Normal  11.699405
# 1437       0     11   2008       New        Partial  12.885671
# 1438       0      4   2010        WD         Normal  11.916389
# 1439       0     11   2007        WD         Normal  12.190959
# 1440       0      9   2008        WD         Normal  12.160029
# 1442       0      4   2009        WD         Normal  12.644328
# 1444       0     11   2007        WD         Normal  12.098487
# 1445       0      5   2007        WD         Normal  11.767568
# 1447       0     12   2007        WD         Normal  12.388394
# 1448       0      5   2007        WD         Normal  11.626254
# 1451       0      5   2009       New        Partial  12.567551
# 1452       0      5   2006        WD         Normal  11.884489
# 1454       0     10   2009        WD         Normal  12.128111
# 1455       0      8   2007        WD         Normal  12.072541
# 1456       0      2   2010        WD         Normal  12.254863
# 1457    2500      5   2010        WD         Normal  12.493130
# 1458       0      4   2010        WD         Normal  11.864462
# 1459       0      6   2008        WD         Normal  11.901583
#
# [1120 rows x 81 columns]

# %%
sp.stats.probplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], plot=plt)
# Out:
# ((array([-3.22392452, -2.96071749, -2.81396581, ...,  2.81396581,
#           2.96071749,  3.22392452]),
#   array([4.65396035, 5.24702407, 5.5759491 , ..., 8.05134093, 8.07277933,
#          8.71768205])),
#  (0.3581237419664907, 6.939738615639688, 0.9899985375257454))

# %%
sns.distplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], fit=sp.stats.norm)
# Out:
# C:\Users\MVJ\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# * And now we have a more normal distribution

# %% [markdown]
# ## Homoscedasticity

# %%
for variable in predictors:
    sns.lmplot(variable, 'SalePrice', data=df_train, scatter_kws={"s": 15})

# %% [markdown]
# * The spread of each variable seems fairly consistently distributed above and below the regression line, but the scatter plot for TotalBsmtSF tells us we still have a problem with this variable outside normality: we performed a log transformation on the non-zero values in that variable a moment ago, but those zeros are still in there, skewing the distribution.

# %%
sns.lmplot('TotalBsmtSF', 'SalePrice', data=df_train[df_train['TotalBsmtSF'] > 0], scatter_kws={"s": 15})
plt.title('Total Basement Square Feet w/o Zeros')
sns.lmplot('TotalBsmtSF', 'SalePrice', data=df_train, scatter_kws={"s": 15})
plt.title('Total Basement Square Feet w/ Zeros')
# Out:
# Text(0.5,1,'Total Basement Square Feet w/ Zeros')

# %% [markdown]
# ## Dummy variable creation

# %%
df_predict = df_train[predictors]
df_predict = pd.get_dummies(df_predict, columns=qual_predictors, drop_first=True)

# %%
df_predict.columns
# Out:
# Index(['GrLivArea', 'TotalBsmtSF', 'OverallQual_3', 'OverallQual_4',
#        'OverallQual_5', 'OverallQual_6', 'OverallQual_7', 'OverallQual_8',
#        'OverallQual_9', 'OverallQual_10', 'GarageCars_2', 'GarageCars_3',
#        'GarageCars_4', 'FullBath_1', 'FullBath_2', 'FullBath_3', 'YearBuilt_1',
#        'YearBuilt_2', 'YearBuilt_3', 'YearBuilt_4', 'YearBuilt_5',
#        'YearBuilt_6', 'YearBuilt_7', 'YearBuilt_8', 'YearBuilt_9',
#        'YearBuilt_10', 'YearBuilt_11', 'YearBuilt_12', 'YearBuilt_13',
#        'YearRemodAdd_8', 'YearRemodAdd_9', 'YearRemodAdd_10',
#        'YearRemodAdd_11', 'YearRemodAdd_12', 'YearRemodAdd_13'],
#       dtype='object')

# %% [markdown]
# ## Testing data

# %%
df_test = pd.read_csv('test.csv')
df_test.set_index('Id', inplace=True)
df_test = df_test[predictors]
df_test.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath',
#        'YearBuilt', 'YearRemodAdd'],
#       dtype='object')

# %%
#We'll have to refactor our yearly variables just as we did in the training data.
for var in ['YearBuilt', 'YearRemodAdd']:
    df_test.loc[df_test[var] <= 1889, var] = 0
    df_test.loc[(df_test[var] >= 1890) & (df_test[var] < 1900), var] = 1
    df_test.loc[(df_test[var] >= 1900) & (df_test[var] < 1910), var] = 2
    df_test.loc[(df_test[var] >= 1910) & (df_test[var] < 1920), var] = 3
    df_test.loc[(df_test[var] >= 1920) & (df_test[var] < 1930), var] = 4
    df_test.loc[(df_test[var] >= 1930) & (df_test[var] < 1940), var] = 5
    df_test.loc[(df_test[var] >= 1940) & (df_test[var] < 1950), var] = 6
    df_test.loc[(df_test[var] >= 1950) & (df_test[var] < 1960), var] = 7
    df_test.loc[(df_test[var] >= 1960) & (df_test[var] < 1970), var] = 8
    df_test.loc[(df_test[var] >= 1970) & (df_test[var] < 1980), var] = 9
    df_test.loc[(df_test[var] >= 1980) & (df_test[var] < 1990), var] = 10
    df_test.loc[(df_test[var] >= 1990) & (df_test[var] < 2000), var] = 11
    df_test.loc[(df_test[var] >= 2000) & (df_test[var] < 2010), var] = 12
    df_test.loc[(df_test[var] >= 2010), var] = 13

# %%
missing_value=df_test.isnull().sum() /len(df_train)
missing_value=pd.DataFrame({'column_name':missing_value.index,'missing_per':missing_value.values})
missing_value[missing_value['missing_per']>0]
# Out:
#    column_name  missing_per
# 2   GarageCars     0.000893
# 3  TotalBsmtSF     0.000893

# %%
## This means that these properties have no basement or no garage, so we'll refactor them as zeros.

df_test['TotalBsmtSF'].fillna(value=0, inplace=True)
df_test['GarageCars'].fillna(value=0, inplace=True)

# And we'll perform a log transformation on the basement area of our testing data just as we did above.


df_test['HasBsmt'] = pd.Series(len(df_test['TotalBsmtSF']), index=df_test.index)
df_test['HasBsmt'] = 0
df_test.loc[df_test['TotalBsmtSF']>0,'HasBsmt'] = 1
df_test.loc[df_test['HasBsmt']==1,'TotalBsmtSF'] = np.log(df_test['TotalBsmtSF'])
df_test['GrLivArea'] = np.log(df_test['GrLivArea'])
# Out:
# C:\Users\MVJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':

# %%
df_test = df_test.drop('HasBsmt', axis=1)

# %% [markdown]
# ### Creating dummy variables

# %%
df_test = pd.get_dummies(df_test, columns=qual_predictors, drop_first=True)
df_test.columns
# Out:
# Index(['GrLivArea', 'TotalBsmtSF', 'OverallQual_2', 'OverallQual_3',
#        'OverallQual_4', 'OverallQual_5', 'OverallQual_6', 'OverallQual_7',
#        'OverallQual_8', 'OverallQual_9', 'OverallQual_10', 'GarageCars_1.0',
#        'GarageCars_2.0', 'GarageCars_3.0', 'GarageCars_4.0', 'GarageCars_5.0',
#        'FullBath_1', 'FullBath_2', 'FullBath_3', 'FullBath_4', 'YearBuilt_1',
#        'YearBuilt_2', 'YearBuilt_3', 'YearBuilt_4', 'YearBuilt_5',
#        'YearBuilt_6', 'YearBuilt_7', 'YearBuilt_8', 'YearBuilt_9',
#        'YearBuilt_10', 'YearBuilt_11', 'YearBuilt_12', 'YearBuilt_13',
#        'YearRemodAdd_8', 'YearRemodAdd_9', 'YearRemodAdd_10',
#        'YearRemodAdd_11', 'YearRemodAdd_12', 'YearRemodAdd_13'],
#       dtype='object')

# %%
df_predict.shape
# Out:
# (1120, 35)

# %%
df_test.columns
# Out:
# Index(['GrLivArea', 'TotalBsmtSF', 'OverallQual_3', 'OverallQual_4',
#        'OverallQual_5', 'OverallQual_6', 'OverallQual_7', 'OverallQual_8',
#        'OverallQual_9', 'OverallQual_10', 'GarageCars_2.0', 'GarageCars_3.0',
#        'GarageCars_4.0', 'FullBath_1', 'FullBath_2', 'FullBath_3',
#        'YearBuilt_1', 'YearBuilt_2', 'YearBuilt_3', 'YearBuilt_4',
#        'YearBuilt_5', 'YearBuilt_6', 'YearBuilt_7', 'YearBuilt_8',
#        'YearBuilt_9', 'YearBuilt_10', 'YearBuilt_11', 'YearBuilt_12',
#        'YearBuilt_13', 'YearRemodAdd_8', 'YearRemodAdd_9', 'YearRemodAdd_10',
#        'YearRemodAdd_11', 'YearRemodAdd_12', 'YearRemodAdd_13'],
#       dtype='object')

# %% [markdown]
# ## Modeling

# %%
X = df_predict
y = df_train['SalePrice']
model = LinearRegression().fit(X, y)

# %%
model.coef_
# Out:
# array([ 2.38800701e-04,  3.91234005e-02,  4.43639123e-01,  5.23357687e-01,
#         6.27534297e-01,  7.04356664e-01,  8.18210977e-01,  9.72501729e-01,
#         1.16674456e+00,  1.05523160e+00,  7.85958447e-02,  1.84512787e-01,
#         1.91900032e-01,  5.57357280e-02,  7.55867864e-02,  1.16783002e-01,
#        -6.89254720e-02,  1.64877237e-02,  7.82334164e-02,  9.92746887e-02,
#         1.66560964e-01,  1.78570918e-01,  2.60905192e-01,  2.50147619e-01,
#         2.32804360e-01,  2.36822452e-01,  2.22288282e-01,  2.29090469e-01,
#         2.16570677e-01,  3.74093884e-02,  1.16201590e-02,  9.49980808e-02,
#         1.42337415e-01,  1.32040635e-01,  2.95032096e-01])

# %%
model.intercept_
# Out:
# 10.228942371589138

# %%
model.score(X, y)
# Out:
# 0.8274668703742756

# %%
results = pd.Series(data=np.exp(model.predict(df_test))).round(0)
results
# Out:
# 0        95486.0
# 1       102032.0
# 2       114049.0
# 3       123145.0
# 4       163060.0
# 5       122217.0
# 6       122987.0
# 7       122373.0
# 8       137084.0
# 9        89145.0
# 10      140258.0
# 11       96461.0
# 12       89622.0
# 13      108855.0
# 14      110433.0
# 15      260448.0
# 16      214201.0
# 17      221829.0
# 18      183174.0
# 19      226382.0
# 20      182565.0
# 21      162926.0
# 22      124438.0
# 23      138649.0
# 24      132853.0
# 25      137037.0
# 26      183026.0
# 27      182218.0
# 28      163591.0
# 29      124945.0
#           ...
# 1429     70383.0
# 1430    102796.0
# 1431     54637.0
# 1432     93779.0
# 1433     60991.0
# 1434    163820.0
# 1435    163902.0
# 1436    111627.0
# 1437    111732.0
# 1438    163470.0
# 1439    110037.0
# 1440    111271.0
# 1441    124645.0
# 1442    182798.0
# 1443    222522.0
# 1444     38076.0
# 1445    156553.0
# 1446     87247.0
# 1447    104878.0
# 1448    114997.0
# 1449     81323.0
# 1450     80879.0
# 1451     93885.0
# 1452     80879.0
# 1453     80879.0
# 1454     80879.0
# 1455     80879.0
# 1456    116210.0
# 1457    103273.0
# 1458    153859.0
# Length: 1459, dtype: float64
