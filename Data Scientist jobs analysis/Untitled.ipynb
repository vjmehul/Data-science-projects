# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import re
import matplotlib.pyplot as plt

joblink2='https://www.indeed.com/viewjob?jk=40f92330a9d649d6'

jobtitle_list=[]
companyname_list=[]
location_list=[]
Publication_req_flag_list=[]
DL_flag_list=[]
PhD_masters_flag_list=[]
other_lang_flag_list=[]
Python_flag_list=[]
Spark_flag_list=[]
Visualization_flag_list=[]
R_flag_list=[]
SAS_flag_list=[]
SQL_flag_list=[]
ML_flag_list=[]
four_years_flag_list=[]
two_years_flag_list=[]
entrylevel_flag_list=[]
five_years_flag_list=[]
seven_years_flag_list=[]
ten_years_flag_list=[]
NLP_flag_list=[]
Scrapping_flag_list=[]
Top_mgmt_flag_list=[]
research_flag_list=[]
Senior_flag_list=[]
entrylevel_flag_list=[]
three_years_flag_list=[]

jobtitle_list=list(jobtitle_list)
companyname_list=list(companyname_list)
location_list=list(location_list)





 
html_page = requests.get(joblink2).text

html_text = BeautifulSoup(html_page, 'html.parser')

job = html_text.findAll("h3", {"class": "icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"})
jobtitle = re.search('none jobsearch-JobInfoHeader-title">(.*)</h3>]', str(job))
jobtitle=jobtitle.group(1)

comp_name= html_text.find_all(attrs={"class": "icl-u-lg-mr--sm icl-u-xs-mr--xs"})
companyname = re.search('icl-u-lg-mr--sm icl-u-xs-mr--xs">(.*)</div>, <div class="icl-u-lg-mr--sm icl', str(comp_name))
companyname=companyname.group(1)

location_info=html_text.head.title
location_info = re.search('\s-\s(.*)\s-\s', str(location_info))
location_info=location_info.group(1)



jobtitle=str(jobtitle)
companyname=str(companyname)
location_info=str(location_info)


discription=html_text.findAll('div',{"class": "jobsearch-JobComponent-description icl-u-xs-mt--md"})
discription=str(discription)
soup2 = BeautifulSoup(discription, 'html.parser')
text=soup2.find_all('li')
text=str(text)
print(len(text))
if not text:
    text=soup2.find_all('div')
    text=str(text)
text=text.replace('</li>','')
text=text.replace('<li>','')
text=text.lower()
textstr=text
print(textstr)
stop_words = set(stopwords.words('english'))
text2=word_tokenize(str(text))

text_list = []
punctuation=['(' ,')' ,"'" ,'.' ,',' ,'<' ,'>' ,'[', ']', '{', '}','/b','/p',':','&',';','p','b','#','i','li','/li','']
for w in text2:
    if w not in stop_words:
        if w not in punctuation:
            text_list.append(w)

Publication_req_flag=0
DL_flag=0
PhD_masters_flag=0
other_lang_flag=0
Python_flag=0
Spark_flag=0
Visualization_flag=0
R_flag=0
SAS_flag=0
SQL_flag=0
ML_flag=0
Spark_flag=0
four_years_flag=0
three_years_flag=0
two_years_flag=0
entrylevel_flag=0
five_years_flag=0
seven_years_flag=0
ten_years_flag=0
NLP_flag=0
Scrapping_flag=0
Top_mgmt_flag=0
research_flag=0
Senior_flag=0
entrylevel_flag=0



pattern=['sigkdd','icml','nips']
for pat in pattern:
    for text in text_list:
        if pat==text:
            Publication_req_flag=1


pattern=['tensorFlow','caffe','keras']
for pat in pattern:
    for text in text_list:
        if pat==text:
            DL_flag=1


pattern=['phd','ph.d','masters',"masters's"]
for pat in pattern:
    for text in text_list:
        if pat==text:
            PhD_masters_flag=1


pattern=['c++','java','scala']
for pat in pattern:
    for text in text_list:
        if pat==text:
            other_lang_flag=1


pattern=['python']
for pat in pattern:
    for text in text_list:
        if pat==text:
            Python_flag=1

pattern=['spark']
for pat in pattern:
    for text in text_list:
        if pat==text:
            Spark_flag=1


pattern=['tableau','chartio','qliksense','qlikview','ggplot2','plotly','matplotlib','seaborn',]
for pat in pattern:
    for text in text_list:
        if pat==text:
            Visualization_flag=1 


pattern=['r']
for pat in pattern:
    for text in text_list:
        if pat==text:
            R_flag=1


pattern=['sas']
for pat in pattern:
    for text in text_list:
        if pat==text:
            SAS_flag=1

pattern=['sql']
for pat in pattern:
    for text in text_list:
        if pat==text:
            SQL_flag=1



patternsML = ['machine learning']
for pattern in patternsML:
    if pattern in textstr:
        ML_flag=1


patternsML = ['apache spark']
for pattern in patternsML:
    if pattern in textstr:
        Spark_flag=1


patternsML = ['4+ years']
for pattern in patternsML:
    if pattern in textstr:
        four_years_flag=1


patternsML = ['3+ years']
for pattern in patternsML:
    if pattern in textstr:
        three_years_flag=1


patternsML = ['2+ years']
for pattern in patternsML:
    if pattern in textstr:
        two_years_flag=1


patternsML = ['0+ years']
for pattern in patternsML:
    if pattern in textstr:
        entrylevel_flag=1



patternsML = ['5+ years']
for pattern in patternsML:
    if pattern in textstr:
        five_years_flag=1


patternsML = ['7+ years']
for pattern in patternsML:
    if pattern in textstr:
        seven_years_flag=1


patternsML = ['10+ years']
for pattern in patternsML:
    if pattern in textstr:
        ten_years_flag=1


patternsML = ['natural language processing','nlp']
for pattern in patternsML:
    if pattern in textstr:
        NLP_flag=1


patternsML = ['deep learning']
for pattern in patternsML:
    if pattern in textstr:
        DL_flag=1


patternsML = ['web scrapping']
for pattern in patternsML:
    if pattern in textstr:
        Scrapping_flag=1

patternsML = ['principle','chief','director','vp','vice president','president']
for pattern in patternsML:
    if pattern in jobtitle:
        Top_mgmt_flag=1

patternsML = ['hadoop','hive','sqoop','pig','zooKeeper','ambari','map reduce']
for pattern in patternsML:
    if pattern in jobtitle:
        big_data_flag=1
        
patternsML = ['mongodb','cassandra','redis','hbase','pig','Neo4j']
for pattern in patternsML:
    if pattern in jobtitle:
        NoSQL_flag=1        
        

patternsML = ['research']
for pattern in patternsML:
    if pattern in textstr:
        research_flag=1


patternsML = ['senior']
for pattern in patternsML:
    if pattern in jobtitle:
        Senior_flag=1


patternsML = ['intern','internship']
for pattern in patternsML:
    if pattern in jobtitle:
        entrylevel_flag=1


jobtitle=str(jobtitle)
companyname=str(companyname)
location_info=str(location_info)

jobtitle_list.append(jobtitle)
companyname_list.append(companyname)
location_list.append(location_info)

Publication_req_flag_list.append(Publication_req_flag)
DL_flag_list.append(DL_flag)
PhD_masters_flag_list.append(PhD_masters_flag)
other_lang_flag_list.append(other_lang_flag)
Python_flag_list.append(Python_flag)
Spark_flag_list.append(Spark_flag)
Visualization_flag_list.append(Visualization_flag)
R_flag_list.append(R_flag)
SAS_flag_list.append(SAS_flag)
SQL_flag_list.append(SQL_flag)
ML_flag_list.append(ML_flag)
three_years_flag_list.append(three_years_flag)
four_years_flag_list.append(four_years_flag)
two_years_flag_list.append(two_years_flag)
five_years_flag_list.append(five_years_flag)
seven_years_flag_list.append(seven_years_flag)
ten_years_flag_list.append(ten_years_flag)
NLP_flag_list.append(NLP_flag)
Scrapping_flag_list.append(Scrapping_flag)
Top_mgmt_flag_list.append(Top_mgmt_flag)
research_flag_list.append(research_flag)
Senior_flag_list.append(Senior_flag)
entrylevel_flag_list.append(entrylevel_flag)

df = pd.DataFrame({ 'Job title': jobtitle_list,
                   'Job link': joblink2,
                   'location':location_list,
                   'Company_name': companyname_list,
                   'Publication_req_flag': Publication_req_flag_list,
                   'DL_flag': DL_flag_list,
                   'PhD_masters_flag': PhD_masters_flag_list,
                   'other_lang_flag': other_lang_flag_list,
                   'Python_flag': Python_flag_list,
                   'Spark_flag': Spark_flag_list,
                   'Visualization_flag': Visualization_flag_list,
                   'R_flag': R_flag_list,
                   'SAS_flag': SAS_flag_list,
                   'SQL_flag': SQL_flag_list,
                   'ML_flag': ML_flag_list,
                   'three_years_flag':three_years_flag_list,
                   'four_years_flag': four_years_flag_list,
                   'two_years_flag': two_years_flag_list,
                   'entrylevel_flag': entrylevel_flag_list,
                   'five_years_flag': five_years_flag_list,
                   'seven_years_flag': seven_years_flag_list,
                   'ten_years_flag': ten_years_flag_list,
                   'NLP_flag': NLP_flag_list,
                   'Scrapping_flag': Scrapping_flag_list,
                   'Top_mgmt_flag': Top_mgmt_flag_list,
                   'research_flag': research_flag_list,
                   'Senior_flag': Senior_flag_list,
                   'entrylevel_flag': entrylevel_flag_list})
# Out:
# 2
# []

# %%
pd.set_option('display.max_columns', 500)
df
# Out:
#             Company_name  DL_flag  \
# 0  University of Wyoming        0
#
#                                             Job link  \
# 0  https://www.indeed.com/viewjob?jk=40f92330a9d6...
#
#                                     Job title  ML_flag  NLP_flag  \
# 0  Lecturer,Asst - Chief Data Science Officer        0         0
#
#    PhD_masters_flag  Publication_req_flag  Python_flag  R_flag  SAS_flag  \
# 0                 0                     0            0       0         0
#
#    SQL_flag  Scrapping_flag  Senior_flag  Spark_flag  Top_mgmt_flag  \
# 0         0               0            0           0              0
#
#    Visualization_flag  entrylevel_flag  five_years_flag  four_years_flag  \
# 0                   0                0                0                0
#
#                                    location  other_lang_flag  research_flag  \
# 0  Chief Data Science Officer - Laramie, WY                0              0
#
#    seven_years_flag  ten_years_flag  three_years_flag  two_years_flag
# 0                 0               0                 0               0

# %%
soup2.find_all('div')
# Out:
# [<div class="jobsearch-JobComponent-description icl-u-xs-mt--md">Please Note
#  <br/><br/>
#  The University of Wyoming invites diverse applicants to consider our employment opportunities. We are also especially interested in candidates who have experience working with diverse populations and/or diverse initiatives.
#  <br/><br/>
#  The University of Wyoming’s College of Education invites applications from dynamic, qualified candidates with a strong background in educational research, statistics, and/or data science for a position as a full-time, benefitted Academic Professional Lecturer (APL) to serve as the College’s chief data science officer and teach 1–2 graduate level courses in educational research or applied data sciences as needed. The individual who ultimately occupies this position must be proficient in software utilized to collect, analyze and report data sets of various sizes and types. In addition, the individual must be able to listen carefully to faculty and administrative personnel in the College of Education and to our collaborative partners in the P–12 settings to interpret and meet continuous program, faculty productivity, and policy improvement needs. Ability to work effectively in collaborative settings, and autonomously is of critical importance. Responsibilities associated with the position include, but are not limited to creating statistical models, utilizing statistical software (e.g., SPSS, SAS, R), designing and development of surveys using software like Qualtrics to answer programmatic questions and organize data for interpretation, reporting, and use in continuous program, faculty productivity, and policy improvement. Preferred qualities include an understanding of educational assessment and/or educational research, as well as previous experience with national accreditation and/or specialized program accreditation reviews.
#  <br/><br/>
#  Minimum Qualifications
#  <br/><br/>
#  An earned doctorate in applied statistics, data science, research methods, educational psychology, applied psychometrics, or closely related field (master's or ABD is acceptable).
#  <br/>Strong background in applied statistics to include data collection, entry, analysis, reporting, and data visualization.
#  <br/>Experience working with government, accreditation, licensing, and other education or policy and program agencies and staffs.
#  <br/>Strong statistical and psychometric knowledge, e.g., multiple regression, logistic regression, data visualization, instrument design, and effectively presented written and verbal reports.
#  <br/>Demonstration of commitment to diversity and inclusion.
#  <br/>Demonstrated or potential ability to work within and across multidisciplinary and cross-functional teams is essential (e.g., with other data scientists across campus to answer “big” data questions.).
#  <br/>Demonstrated effectiveness as a college-level classroom instructor at the undergraduate or graduate levels.
#  <br/><br/>
#  Desired Qualifications
#  <br/><br/>
#  Experience or potential for collaborating with internal and external stakeholders.
#  <br/>Experience or potential for collaborating with faculty, staff, and state licensing agencies, P–12 educational constituencies, on reports for accreditation (e.g., CAEP, SPAs), legislative compliance and program improvement.
#  <br/><br/>
#  Required Materials
#  <br/><br/>
#  Complete on-line application and upload the following as one document : cover letter, cv, contact information for four (4) work-related references, two (2) of which should be current or previous supervisors, a teaching philosophy statement, and evidence of teaching effectiveness including student evaluations.
#  <br/><br/>
#  Hiring Statement
#  <br/><br/>
#  The University of Wyoming is an Equal Employment Opportunity/Affirmative Action employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, disability or protected veteran status or any other characteristic protected by law and University policy. To review the EEO is the Law Poster and its Supplement , please see The Diversity &amp; Fairness page .
#  <br/>Pursuant to Wyoming State law, W.S. 19-14-102, as amended, an honorably discharged veteran who has been a resident of the state of Wyoming for one (1) year or more at any time prior to the date when the veteran applies for employment, or any surviving spouse who was married to such veteran at the time of the veteran’s death, who is receiving federal survivor benefits based on the veteran’s military service and is applying for employment, shall receive an interview preference during the applicant screening process with the University of Wyoming. At the time of application the applicant must possess the business capacity, competency, education or other qualifications required for the position. If disabilities do not materially interfere with performance of job duties, disabled veterans will be given preference over able-bodied veterans. Appropriate documentation of veteran status must be provided at time of application as outlined in the application process. No preference will be given to a veteran currently employed by a public department.
#  <br/>We conduct background investigations for all final candidates being considered for employment. Offers of employment are contingent upon the completion of the background check.
#  <br/>Applicants with disabilities may request accommodation to complete the application and selection process. Please notify Human Resources at least three (3) working days prior to the date of need.
#  <br/><br/>
#  Welcome to Laramie
#  <br/><br/>
#  The University of Wyoming is located in Laramie, a town of 30,000 in the heart of the Rocky Mountain West. The state of Wyoming continues to invest in its university, helping to make it a leader in academics, research and outreach. The university has state-of-the-art facilities in many areas and the community provides the advantages of a major university.
#  <br/>Located in a high mountain valley near the Colorado border, Laramie offers both outstanding recreational opportunities and close proximity to Colorado’s Front Range, a bustling group of metropolitan cities including Denver, Boulder, and Fort Collins. This beautiful mountain landscape offers outdoor enjoyment in all seasons, with over 300 days of sunshine annually. For more information about the region, please visit http://visitlaramie.org/</div>]

# %%
patternsML = ['3+ years','3+ Years']
for pattern in patternsML:
    if pattern in text:
        three_years_flag=1
        print ('voila')

# %%
x
# Out:
# 'Develop experiments to reduce friction in the listing creation process for hosts, Designing experiments to measure the lift when displaying hotel rooms on our platform, Create product experiments (on service fees, early demand, etc) and measure the impact on market dynamics (such as competitors)., Improve the statistical methodology behind our experimentation platform to ensure that our understanding of product changes is rigorous and accurate, 4 Principles for Making Experimentation Count ( https://medium.com/airbnb-engineering/4-principles-for-making-experimentation-count-7a5f1a5268a ), Scaling Airbnbs Experimentation Platform ( https://medium.com/airbnb-engineering/https-medium-com-jonathan-parks-scaling-erf-23fd17c91166 ), A passion for Airbnbs mission of helping people Belong Anywhere, Ability to write clean and concise code, especially in R or Python, 3+ years in industry experience and a Masters degree in a quantitative field or Economics; PhD is a plus, Solid understanding of statistics, Keen eye for detail and thoughtful investigation of data before relying upon it, Intuition for data science best practices, stemming from proven experience, Steadfast focus on creating impactful change, Ability to partner with cross-functional teams using strong written and verbal communication'

# %%
s = " Masters degree in a quantitative field or Economics; PhD is a plus, Solid understanding of statistics"
print(s.lower())
# Out:
#  masters degree in a quantitative field or economics; phd is a plus, solid understanding of statistics

# %%
html_page = requests.get(joblink2).text

html_text = BeautifulSoup(html_page, 'html.parser')
